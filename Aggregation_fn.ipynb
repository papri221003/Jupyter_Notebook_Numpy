# %%
import numpy as np 
array=np.array([10,20,30,40,50])

print(np.sum(array))
print(np.mean(array))
print(np.min(array))
print(np.max(array))
print(np.std(array))
print(np.var(array))
# Out:
# 150
# 30.0
# 10
# 50
# 14.142135623730951
# 200.0
