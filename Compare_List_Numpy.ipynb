# %%
# %timeit [j**4 for j in range(1,1000)]
# Out:
# 126 μs ± 6.15 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
import numpy as np
# %timeit np.arange(1,1000)**4
# Out:
# 7.4 μs ± 1.24 μs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
