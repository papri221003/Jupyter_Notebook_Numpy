# %%
# %timeit [j**4 for j in range(1,1000)]
# Out:
# 53.3 μs ± 1.3 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
import numpy as np
# %timeit np.arange(1,1000)**4
# Out:
# 2.98 μs ± 97.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
